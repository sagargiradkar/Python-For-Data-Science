# %%
import pandas as pd

# %%
df = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
type(df)
# Out:
# list

# %%
df
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#       DRB  TRB  AST  STL BLK  TOV   PF   PTS
#  0    222  301   68   27  22   60  147   398
#  1     19   28   16   16   7   14   24    94
#  2    324  523   66   38  86   99  222   537
#  3     54   77   15    4   9    9   30    60
#  4    220  247  129   41   7  116  167  1035
#  ..   ...  ...  ...  ...  ..  ...  ...   ...
#  670  284  411  173  124  25  117  171  1071
#  671  170  245  135   86  17   75  115   685
#  672  114  166   38   38   8   42   56   386
#  673  265  362  100   34  49   62  156   472
#  674  319  465  113   18  52   76  205   833
#
#  [675 rows x 30 columns]]

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
df1 = df[0]

# %%
df1.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df1.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df1.tail()
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [5 rows x 30 columns]

# %%
df1.head(3)
# Out:
#   Rk        Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1    Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2  Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3  Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
#
#    TRB AST STL BLK TOV   PF  PTS
# 0  301  68  27  22  60  147  398
# 1   28  16  16   7  14   24   94
# 2  523  66  38  86  99  222  537
#
# [3 rows x 30 columns]

# %%
df1.tail(10)
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 665  485  Brandan Wright  PF  27  PHO  40   7   858  120  207  ...  .667   70
# 666  486   Dorell Wright  SF  29  POR  48   2   592   72  190  ...  .810   14
# 667  487     Tony Wroten  PG  21  PHI  30  15   895  175  434  ...  .667   22
# 668  488     James Young  SG  19  BOS  31   0   332   36  102  ...  .552    9
# 669  489      Nick Young  SG  29  LAL  42   0  1000  174  476  ...  .892   17
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 665  124  194   23   32  47   16   54   280
# 666   97  111   41   20  11   18   55   219
# 667   64   86  157   48   8  113   72   507
# 668   33   42   13    8   2    5   22   105
# 669   79   96   41   23  11   44   83   563
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [10 rows x 30 columns]

# %%
df1.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df1[['Age','GS']]
# Out:
#     Age  GS
# 0    24  22
# 1    20   0
# 2    21  67
# 3    28   0
# 4    29  72
# ..   ..  ..
# 670  26  68
# 671  26  48
# 672  26  20
# 673  22  45
# 674  25  59
#
# [675 rows x 2 columns]

# %%
df1.tail(100)
# Out:
#       Rk            Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  \
# 575  421    Tiago Splitter   C  30  SAS  52  35  1030  169  303  ...  .750
# 576  422      Nik Stauskas  SG  21  SAC  73   1  1127  108  296  ...  .859
# 577  423  Lance Stephenson  SG  24  CHO  61  25  1573  207  550  ...  .627
# 578  424     Greg Stiemsma   C  29  TOR  17   0    66    6    8  ...  .500
# 579  425    David Stockton  PG  23  SAC   3   0    33    2    6  ...  .500
# ..   ...               ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...
# 670  490    Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655
# 671  490    Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682
# 672  490    Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606
# 673  491       Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774
# 674  492      Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823
#
#      ORB  DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 575   91  161  252   78   35  37   60  103   428
# 576   11   77   88   67   20  17   40   92   319
# 577   39  238  277  240   38   8  128  134   501
# 578    9    6   15    3    2   0    7   15    14
# 579    0    2    2    9    2   0    4    1     8
# ..   ...  ...  ...  ...  ...  ..  ...  ...   ...
# 670  127  284  411  173  124  25  117  171  1071
# 671   75  170  245  135   86  17   75  115   685
# 672   52  114  166   38   38   8   42   56   386
# 673   97  265  362  100   34  49   62  156   472
# 674  146  319  465  113   18  52   76  205   833
#
# [100 rows x 30 columns]

# %%
df1
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
df1.to_csv("NBA.csv",index=False)

# %%
ls
# Out:
#  addresses.csv
#  contacts.csv
#  holiday_schedules.csv
#  locations.csv
# 'LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx'
# 'LUSID Excel - Maintain a product in multiple currencies and share classes.xlsx'
# 'LUSID Excel - Manage instruments with economic definitions.xlsx'
# 'LUSID Excel - Manage Orders.xlsx'
# 'LUSID Excel - Manage your investment strategies.xlsx'
# 'LUSID Excel - Setting up your IBOR.xlsx'
# 'LUSID Excel - Setting up your market data.xlsx'
#  mail_addresses.csv
#  NBA.csv
#  organizations.csv
#  pandas-2.ipynb
#  Pandas.ipynb
#  phones.csv
#  programs.csv
#  regular_schedules.csv
#  services.csv
#  taxonomy.csv

# %%
pd.read_csv("NBA.csv")
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
d = """
{"Name":"sagar giradkar",
"Email id":"spgiradkar2002@gmail.com",
"Tech":["ML","DL","CV"],
"Platform":"techneuron"
}
"""
type(d)
# Out:
# str

# %%
import json

# %%
result = json.loads(d)

# %%
result
# Out:
# {'Name': 'sagar giradkar',
#  'Email id': 'spgiradkar2002@gmail.com',
#  'Tech': ['ML', 'DL', 'CV'],
#  'Platform': 'techneuron'}

# %%
type(result)
result["Name"]
# Out:
# 'sagar giradkar'

# %%
pd.DataFrame(result["Tech"])
# Out:
#     0
# 0  ML
# 1  DL
# 2  CV

# %%
pd.DataFrame(result["Tech"])
# Out:
#     0
# 0  ML
# 1  DL
# 2  CV

# %%
pd.DataFrame(["Data"])
# Out:
#       0
# 0  Data

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0     https://github.com/pandas-dev/pandas/pull/54707  1863046827
# 1   https://github.com/pandas-dev/pandas/issues/54706  1862930076
# 2     https://github.com/pandas-dev/pandas/pull/54705  1862693327
# 3     https://github.com/pandas-dev/pandas/pull/54704  1862641777
# 4     https://github.com/pandas-dev/pandas/pull/54703  1862635701
# 5   https://github.com/pandas-dev/pandas/issues/54702  1862544294
# 6     https://github.com/pandas-dev/pandas/pull/54701  1862539435
# 7     https://github.com/pandas-dev/pandas/pull/54699  1862361451
# 8     https://github.com/pandas-dev/pandas/pull/54696  1862287718
# 9   https://github.com/pandas-dev/pandas/issues/54695  1862152809
# 10    https://github.com/pandas-dev/pandas/pull/54687  1861239432
# 11  https://github.com/pandas-dev/pandas/issues/54686  1861211626
# 12  https://github.com/pandas-dev/pandas/issues/54682  1860933826
# 13    https://github.com/pandas-dev/pandas/pull/54681  1860614640
# 14    https://github.com/pandas-dev/pandas/pull/54679  1860306365
# 15  https://github.com/pandas-dev/pandas/issues/54677  1860280020
# 16    https://github.com/pandas-dev/pandas/pull/54675  1860210094
# 17  https://github.com/pandas-dev/pandas/issues/54671  1860026324
# 18  https://github.com/pandas-dev/pandas/issues/54668  1859900871
# 19    https://github.com/pandas-dev/pandas/pull/54666  1859834534
# 20  https://github.com/pandas-dev/pandas/issues/54665  1859781705
# 21  https://github.com/pandas-dev/pandas/issues/54661  1859583020
# 22  https://github.com/pandas-dev/pandas/issues/54660  1859284386
# 23  https://github.com/pandas-dev/pandas/issues/54659  1859151730
# 24  https://github.com/pandas-dev/pandas/issues/54657  1858727363
# 25  https://github.com/pandas-dev/pandas/issues/54656  1858492723
# 26  https://github.com/pandas-dev/pandas/issues/54654  1858285780
# 27    https://github.com/pandas-dev/pandas/pull/54653  1858275287
# 28  https://github.com/pandas-dev/pandas/issues/54651  1858222111
# 29    https://github.com/pandas-dev/pandas/pull/54649  1858182626
#
#                 node_id  number  \
# 0   PR_kwDOAA0YD85YlS1d   54707
# 1    I_kwDOAA0YD85vCg6c   54706
# 2   PR_kwDOAA0YD85YkGis   54705
# 3   PR_kwDOAA0YD85Yj7fX   54704
# 4   PR_kwDOAA0YD85Yj6MG   54703
# 5    I_kwDOAA0YD85vBCum   54702
# 6   PR_kwDOAA0YD85Yjlmt   54701
# 7   PR_kwDOAA0YD85YjATa   54699
# 8   PR_kwDOAA0YD85YiwaU   54696
# 9    I_kwDOAA0YD85u_jJp   54695
# 10  PR_kwDOAA0YD85YfKX_   54687
# 11   I_kwDOAA0YD85u79Xq   54686
# 12   I_kwDOAA0YD85u65jC   54682
# 13  PR_kwDOAA0YD85YdAEC   54681
# 14  PR_kwDOAA0YD85Yb94t   54679
# 15   I_kwDOAA0YD85u4Z7U   54677
# 16  PR_kwDOAA0YD85Yboan   54675
# 17   I_kwDOAA0YD85u3b_U   54671
# 18   I_kwDOAA0YD85u29XH   54668
# 19  PR_kwDOAA0YD85YaVpO   54666
# 20   I_kwDOAA0YD85u2gRJ   54665
# 21   I_kwDOAA0YD85u1vws   54661
# 22   I_kwDOAA0YD85u0m2i   54660
# 23   I_kwDOAA0YD85u0Gdy   54659
# 24   I_kwDOAA0YD85uye3D   54657
# 25   I_kwDOAA0YD85uxlkz   54656
# 26   I_kwDOAA0YD85uwzDU   54654
# 27  PR_kwDOAA0YD85YVC-c   54653
# 28   I_kwDOAA0YD85uwjgf   54651
# 29  PR_kwDOAA0YD85YUwlT   54649
#
#                                                 title  ... closed_at  \
# 0   BUG: ArrowExtensionArray.fillna with duration ...  ...       NaT
# 1   BUG: creating dataframe from masked numpy arra...  ...       NaT
# 2   DOC: updated date_format description for read_csv  ...       NaT
# 3     DEPR: deprecated nonkeyword arguments in to_gbq  ...       NaT
# 4   DEPR: deprecated nonkeyword arguments in to_excel  ...       NaT
# 5   BUG: `pd.Timestamp()` only raises for nonexist...  ...       NaT
# 6             TST: added test for fixed bug  gh#50372  ...       NaT
# 7   BUG: setitem with object type inserting Series...  ...       NaT
# 8   DOC: fix an example which raises an Error in v...  ...       NaT
# 9   BUG: Formatting MultiIndex crashes if first co...  ...       NaT
# 10                    BUG: Fix astype str issue 54654  ...       NaT
# 11  BUG: can't install 2.1.0rc0. "Inconsistent ver...  ...       NaT
# 12  BUG: support non-nanos Timedelta objects in Py...  ...       NaT
# 13                   Bug Fix for documentation: 54547  ...       NaT
# 14  Incorrect reading of CSV containing large inte...  ...       NaT
# 15          ENH: add `atol` to pd.DataFrame.compare()  ...       NaT
# 16                       Smcbeth/series write parquet  ...       NaT
# 17  BUG: PyArrow-backed DataFrame not exportable t...  ...       NaT
# 18  API: Make searchsorted raise TypeError on mism...  ...       NaT
# 19                      ENH: numba engine in df.apply  ...       NaT
# 20                                              BUG:   ...       NaT
# 21  BUG: is_string_dtype(pd.Index([], dtype='O')) ...  ...       NaT
# 22  PDEP-6: special case (allow) upcasting to floa...  ...       NaT
# 23  BUG: read_pickle omit timezone when reading ol...  ...       NaT
# 24  ENH: let .dt.isocalendar() return float64 in p...  ...       NaT
# 25     BUG: Inconsistent behaviour of is_string_dtype  ...       NaT
# 26  BUG: ensure_string_array may change the array ...  ...       NaT
# 27  DOC: fix build failure with sphinx 7 and SOURC...  ...       NaT
# 28   BUG: pd.to_sql fails with an ARRAY of composites  ...       NaT
# 29     Updated documentation for pandas.DataFrame.map  ...       NaT
#
#    author_association active_lock_reason  draft  \
# 0         CONTRIBUTOR                NaN    0.0
# 1                NONE                NaN    NaN
# 2         CONTRIBUTOR                NaN    0.0
# 3         CONTRIBUTOR                NaN    0.0
# 4         CONTRIBUTOR                NaN    0.0
# 5                NONE                NaN    NaN
# 6                NONE                NaN    0.0
# 7              MEMBER                NaN    0.0
# 8         CONTRIBUTOR                NaN    0.0
# 9                NONE                NaN    NaN
# 10               NONE                NaN    0.0
# 11               NONE                NaN    NaN
# 12             MEMBER                NaN    NaN
# 13               NONE                NaN    0.0
# 14        CONTRIBUTOR                NaN    0.0
# 15               NONE                NaN    NaN
# 16               NONE                NaN    0.0
# 17        CONTRIBUTOR                NaN    NaN
# 18             MEMBER                NaN    NaN
# 19             MEMBER                NaN    0.0
# 20               NONE                NaN    NaN
# 21        CONTRIBUTOR                NaN    NaN
# 22             MEMBER                NaN    NaN
# 23               NONE                NaN    NaN
# 24               NONE                NaN    NaN
# 25               NONE                NaN    NaN
# 26               NONE                NaN    NaN
# 27        CONTRIBUTOR                NaN    0.0
# 28               NONE                NaN    NaN
# 29               NONE                NaN    0.0
#
#                                          pull_request  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1                                                 NaN
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5                                                 NaN
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9                                                 NaN
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11                                                NaN
# 12                                                NaN
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15                                                NaN
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17                                                NaN
# 18                                                NaN
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28                                                NaN
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                                  body  \
# 0   - [x] [Tests added and passed](https://pandas....
# 1   ### Pandas version checks\n\n- [X] I have chec...
# 2   - [ ] xref #54285 \r\n- [ ] [Tests added and p...
# 3   - [x] xref #54229\r\n- [ ] [Tests added and pa...
# 4   - [x] xref #54229 \r\n- [x] [Tests added and p...
# 5   ### Pandas version checks\r\n\r\n- [X] I have ...
# 6   - [x] closes #50372 \r\n- [x] [Tests added and...
# 7   - [x] closes #48933 (Replace xxxx with the Git...
# 8   Fix an example in doc/source/whatsnew/v0.13.0....
# 9   ### Pandas version checks\n\n- [X] I have chec...
# 10  - [ ] closes #54654\r\n- [ ] [Tests added and ...
# 11  ### Pandas version checks\r\n\r\n- [X] I have ...
# 12  See https://github.com/apache/arrow/issues/372...
# 13  Updating documents based on suggestions.\r\n\r...
# 14  - [ ] closes #52505\r\n- [ ] All [code checks ...
# 15  ### Feature Type\n\n- [X] Adding new functiona...
# 16  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 17  ### Pandas version checks\r\n\r\n- [X] I have ...
# 18  ```python\r\nIn [1]: import pandas as pd\r\n\r...
# 19  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 20  ### Pandas version checks\r\n\r\n- [X] I have ...
# 21  ### Pandas version checks\r\n\r\n- [X] I have ...
# 22  Currently, on the main branch with the PDEP-6 ...
# 23  ### Pandas version checks\n\n- [X] I have chec...
# 24  ### Feature Type\n\n- [ ] Adding new functiona...
# 25  ### Pandas version checks\n\n- [X] I have chec...
# 26  ### Pandas version checks\n\n- [X] I have chec...
# 27  When SOURCE_DATE_EPOCH is set (which is the de...
# 28  ### Pandas version checks\r\n\r\n- [X] I have ...
# 29  closes issue #54648 by adding another example ...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#    performed_via_github_app state_reason
# 0                       NaN          NaN
# 1                       NaN          NaN
# 2                       NaN          NaN
# 3                       NaN          NaN
# 4                       NaN          NaN
# 5                       NaN          NaN
# 6                       NaN          NaN
# 7                       NaN          NaN
# 8                       NaN          NaN
# 9                       NaN          NaN
# 10                      NaN          NaN
# 11                      NaN          NaN
# 12                      NaN          NaN
# 13                      NaN          NaN
# 14                      NaN          NaN
# 15                      NaN          NaN
# 16                      NaN          NaN
# 17                      NaN          NaN
# 18                      NaN          NaN
# 19                      NaN          NaN
# 20                      NaN          NaN
# 21                      NaN          NaN
# 22                      NaN          NaN
# 23                      NaN          NaN
# 24                      NaN          NaN
# 25                      NaN          NaN
# 26                      NaN          NaN
# 27                      NaN          NaN
# 28                      NaN          NaN
# 29                      NaN          NaN
#
# [30 rows x 30 columns]

# %%
import requests

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
data = requests.get(url)

# %%
data1 = data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54707',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54707/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54707/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54707/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54707',
#   'id': 1863046827,
#   'node_id': 'PR_kwDOAA0YD85YlS1d',
#   'number': 54707,
#   'title': 'BUG: ArrowExtensionArray.fillna with duration types',
#   'user': {'login': 'lukemanley',
#    'id': 8519523,
#    'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lukemanley',
#    'html_url': 'https://github.com/lukemanley',
#    'followers_url': 'https://api.github.com/users/lukemanley/followers',
#    'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#    'repos_url': 'https://api.github.com/users/lukemanley/repos',
#    'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 3303158446,
#     'node_id': 'MDU6TGFiZWwzMzAzMTU4NDQ2',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Arrow',
#     'name': 'Arrow',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': 'pyarrow functionality'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-08-23T10:29:28Z',
#   'updated_at': '2023-08-23T10:32:02Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54707',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54707',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54707.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54707.patch',
#    'merged_at': None},
#   'body': '- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n\r\ncc @mroeschke - this expands on #54678 to cover a few more cases. \r\n\r\n\r\n\r\n\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54707/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54707/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54706',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54706/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54706/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54706/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/54706',
#   'id': 1862930076,
#   'node_id': 'I_kwDOAA0YD85vCg6c',
#   'number': 54706,
#   'title': 'BUG: creating dataframe from masked numpy array turns missing string values into NaN',
#   'user': {'login': 'mvashishtha',
#    'id': 10712109,
#    'node_id': 'MDQ6VXNlcjEwNzEyMTA5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10712109?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mvashishtha',
#    'html_url': 'https://github.com/mvashishtha',
#    'followers_url': 'https://api.github.com/users/mvashishtha/followers',
#    'following_url': 'https://api.github.com/users/mvashishtha/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mvashishtha/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mvashishtha/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mvashishtha/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mvashishtha/orgs',
#    'repos_url': 'https://api.github.com/users/mvashishtha/repos',
#    'events_url': 'https://api.github.com/users/mvashishtha/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mvashishtha/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-08-23T09:25:28Z',
#   'updated_at': '2023-08-23T09:40:07Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\nimport numpy as np\r\nimport numpy.ma as ma\r\n\r\nx = np.array(['a', 'b'])\r\nmx = ma.masked_array(x, mask=[0, 1])\r\nprint(pd.DataFrame(mx))\n```\n\n\n### Issue Description\n\ncreating dataframe from masked numpy array turns missing string values into NaN\n\n### Expected Behavior\n\nFor examples like this, where the masked array is of string dtype, I expect pandas to fill missing data with `None` instead of `NaN`.\n\n### Installed Versions\n\n<details>\r\n<summary>Details</summary>\r\n\r\n```\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 0f437949513225922d851e9581723d82120684a6\r\npython           : 3.8.16.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 22.5.0\r\nVersion          : Darwin Kernel Version 22.5.0: Mon Apr 24 20:51:50 PDT 2023; root:xnu-8796.121.2~5/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 2.0.3\r\nnumpy            : 1.24.4\r\npytz             : 2023.3\r\ndateutil         : 2.8.2\r\nsetuptools       : 67.8.0\r\npip              : 23.1.2\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : None\r\nIPython          : 8.12.2\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsnappy           : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nzstandard        : None\r\ntzdata           : 2023.3\r\nqtpy             : None\r\npyqt5            : None\r\n```\r\n\r\n</details>\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54706/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54706/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54705',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54705/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54705/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54705/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54705',
#   'id': 1862693327,
#   'node_id': 'PR_kwDOAA0YD85YkGis',
#   'number': 54705,
#   'title': 'DOC: updated date_format description for read_csv',
#   'user': {'login': 'rsm-23',
#    'id': 136445532,
#    'node_id': 'U_kgDOCCH-XA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/136445532?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rsm-23',
#    'html_url': 'https://github.com/rsm-23',
#    'followers_url': 'https://api.github.com/users/rsm-23/followers',
#    'following_url': 'https://api.github.com/users/rsm-23/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rsm-23/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rsm-23/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rsm-23/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rsm-23/orgs',
#    'repos_url': 'https://api.github.com/users/rsm-23/repos',
#    'events_url': 'https://api.github.com/users/rsm-23/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rsm-23/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-08-23T06:59:08Z',
#   'updated_at': '2023-08-23T06:59:08Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54705',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54705',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54705.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54705.patch',
#    'merged_at': None},
#   'body': '- [ ] xref #54285 \r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54705/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54705/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54704',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54704/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54704/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54704/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54704',
#   'id': 1862641777,
#   'node_id': 'PR_kwDOAA0YD85Yj7fX',
#   'number': 54704,
#   'title': 'DEPR: deprecated nonkeyword arguments in to_gbq',
#   'user': {'login': 'rsm-23',
#    'id': 136445532,
#    'node_id': 'U_kgDOCCH-XA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/136445532?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rsm-23',
#    'html_url': 'https://github.com/rsm-23',
#    'followers_url': 'https://api.github.com/users/rsm-23/followers',
#    'following_url': 'https://api.github.com/users/rsm-23/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rsm-23/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rsm-23/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rsm-23/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rsm-23/orgs',
#    'repos_url': 'https://api.github.com/users/rsm-23/repos',
#    'events_url': 'https://api.github.com/users/rsm-23/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rsm-23/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-08-23T06:18:06Z',
#   'updated_at': '2023-08-23T09:17:02Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54704',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54704',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54704.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54704.patch',
#    'merged_at': None},
#   'body': '- [x] xref #54229\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added an entry in the latest `doc/source/whatsnew/v2.2.0.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54704/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54704/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54703',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54703/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54703/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54703/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54703',
#   'id': 1862635701,
#   'node_id': 'PR_kwDOAA0YD85Yj6MG',
#   'number': 54703,
#   'title': 'DEPR: deprecated nonkeyword arguments in to_excel',
#   'user': {'login': 'rsm-23',
#    'id': 136445532,
#    'node_id': 'U_kgDOCCH-XA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/136445532?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rsm-23',
#    'html_url': 'https://github.com/rsm-23',
#    'followers_url': 'https://api.github.com/users/rsm-23/followers',
#    'following_url': 'https://api.github.com/users/rsm-23/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rsm-23/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rsm-23/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rsm-23/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rsm-23/orgs',
#    'repos_url': 'https://api.github.com/users/rsm-23/repos',
#    'events_url': 'https://api.github.com/users/rsm-23/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rsm-23/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-08-23T06:12:42Z',
#   'updated_at': '2023-08-23T09:16:24Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54703',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54703',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54703.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54703.patch',
#    'merged_at': None},
#   'body': '- [x] xref #54229 \r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added an entry in the latest `doc/source/whatsnew/v2.2.0.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54703/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54703/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54702',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54702/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54702/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54702/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/54702',
#   'id': 1862544294,
#   'node_id': 'I_kwDOAA0YD85vBCum',
#   'number': 54702,
#   'title': 'BUG: `pd.Timestamp()` only raises for nonexistent times when instantiated using str `ts_input`',
#   'user': {'login': 'leonoverweel',
#    'id': 7980521,
#    'node_id': 'MDQ6VXNlcjc5ODA1MjE=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7980521?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/leonoverweel',
#    'html_url': 'https://github.com/leonoverweel',
#    'followers_url': 'https://api.github.com/users/leonoverweel/followers',
#    'following_url': 'https://api.github.com/users/leonoverweel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/leonoverweel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/leonoverweel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/leonoverweel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/leonoverweel/orgs',
#    'repos_url': 'https://api.github.com/users/leonoverweel/repos',
#    'events_url': 'https://api.github.com/users/leonoverweel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/leonoverweel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-08-23T04:26:09Z',
#   'updated_at': '2023-08-23T04:41:40Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd\r\n\r\n# Nonexistent time, but doesn\'t raise:\r\nt1 = pd.Timestamp(2023, 3, 26, 2, 0, 0, tz="Europe/Amsterdam")\r\n\r\n# Same nonexistent time, but does raise:\r\nt2 = pd.Timestamp("2023-03-26 02:00", tz="Europe/Amsterdam")\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nWhen instantiating a nonexistent time, I would expect both ways of instantiating that time -- (1) using the `year`, `month`, `day`, `hour`, `minute` parameters and (2) using a (string) `ts_input` parameter -- to have the same result.\r\n\r\nHowever, option (1) happily accepts this nonexistent time, while option (2) correctly raises a `pytz.NonExistentTimeError`\r\n\r\n<details><summary>Full traceback</summary>\r\n\r\n```python\r\nTraceback (most recent call last):\r\n  File "../example.py", line 16, in <module>\r\n    dt2 = pd.Timestamp("2023-03-26 02:00", tz="Europe/Amsterdam")\r\n          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\r\n  File "pandas/_libs/tslibs/timestamps.pyx", line 1667, in pandas._libs.tslibs.timestamps.Timestamp.__new__\r\n  File "pandas/_libs/tslibs/conversion.pyx", line 280, in pandas._libs.tslibs.conversion.convert_to_tsobject\r\n  File "pandas/_libs/tslibs/conversion.pyx", line 547, in pandas._libs.tslibs.conversion.convert_str_to_tsobject\r\n  File "pandas/_libs/tslibs/tzconversion.pyx", line 177, in pandas._libs.tslibs.tzconversion.tz_localize_to_utc_single\r\n  File "pandas/_libs/tslibs/tzconversion.pyx", line 417, in pandas._libs.tslibs.tzconversion.tz_localize_to_utc\r\npytz.exceptions.NonExistentTimeError: 2023-03-26 02:00:00\r\n```\r\n\r\n</details> \r\n\r\n### Expected Behavior\r\n\r\nBoth options (1) and (2) for instantiating a nonexistent time should raise and tell me it\'s a nonexistent time.\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\n```\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 0f437949513225922d851e9581723d82120684a6\r\npython           : 3.11.4.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 22.3.0\r\nVersion          : Darwin Kernel Version 22.3.0: Mon Jan 30 20:38:37 PST 2023; root:xnu-8792.81.3~2/RELEASE_ARM64_T6000\r\nmachine          : arm64\r\nprocessor        : arm\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 2.0.3\r\nnumpy            : 1.25.2\r\npytz             : 2023.3\r\ndateutil         : 2.8.2\r\nsetuptools       : 68.0.0\r\npip              : 23.2.1\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : None\r\nIPython          : None\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsnappy           : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : Non ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54702/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54702/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54701',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54701/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54701/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54701/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54701',
#   'id': 1862539435,
#   'node_id': 'PR_kwDOAA0YD85Yjlmt',
#   'number': 54701,
#   'title': 'TST: added test for fixed bug  gh#50372',
#   'user': {'login': 'DRiXD',
#    'id': 39619011,
#    'node_id': 'MDQ6VXNlcjM5NjE5MDEx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39619011?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DRiXD',
#    'html_url': 'https://github.com/DRiXD',
#    'followers_url': 'https://api.github.com/users/DRiXD/followers',
#    'following_url': 'https://api.github.com/users/DRiXD/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/DRiXD/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/DRiXD/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/DRiXD/subscriptions',
#    'organizations_url': 'https://api.github.com/users/DRiXD/orgs',
#    'repos_url': 'https://api.github.com/users/DRiXD/repos',
#    'events_url': 'https://api.github.com/users/DRiXD/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/DRiXD/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-08-23T04:19:26Z',
#   'updated_at': '2023-08-23T06:20:20Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54701',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54701',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54701.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54701.patch',
#    'merged_at': None},
#   'body': '- [x] closes #50372 \r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests)\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n\r\nI added a test to prevent the bug described in GG#50372 from happening again.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54701/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54701/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54699',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54699/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54699/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54699/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54699',
#   'id': 1862361451,
#   'node_id': 'PR_kwDOAA0YD85YjATa',
#   'number': 54699,
#   'title': 'BUG: setitem with object type inserting Series maintains Series',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2822098,
#     'node_id': 'MDU6TGFiZWwyODIyMDk4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Indexing',
#     'name': 'Indexing',
#     'color': '0b02e1',
#     'default': False,
#     'description': 'Related to indexing on series/frames, not to indexes themselves'},
#    {'id': 2189479765,
#     'node_id': 'MDU6TGFiZWwyMTg5NDc5NzY1',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Nested%20Data',
#     'name': 'Nested Data',
#     'color': 'f2f989',
#     'default': False,
#     'description': 'Data where the values are collections (lists, sets, dicts, objects, etc.).'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/103',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103/labels',
#    'id': 9068593,
#    'node_id': 'MI_kwDOAA0YD84AimAx',
#    'number': 103,
#    'title': '2.1',
#    'description': 'on-merge: backport to 2.1.x',
#    'creator': {'login': 'phofl',
#     'id': 61934744,
#     'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/phofl',
#     'html_url': 'https://github.com/phofl',
#     'followers_url': 'https://api.github.com/users/phofl/followers',
#     'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#     'organizations_url': 'https://api.github.com/users/phofl/orgs',
#     'repos_url': 'https://api.github.com/users/phofl/repos',
#     'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/phofl/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 8,
#    'closed_issues': 1270,
#    'state': 'open',
#    'created_at': '2023-02-20T21:04:36Z',
#    'updated_at': '2023-08-23T03:02:11Z',
#    'due_on': '2023-08-20T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2023-08-23T00:15:22Z',
#   'updated_at': '2023-08-23T00:15:22Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54699',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54699',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54699.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54699.patch',
#    'merged_at': None},
#   'body': '- [x] closes #48933 (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54699/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54699/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54696',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54696/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54696/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54696/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54696',
#   'id': 1862287718,
#   'node_id': 'PR_kwDOAA0YD85YiwaU',
#   'number': 54696,
#   'title': 'DOC: fix an example which raises an Error in v0.13.0.rst',
#   'user': {'login': 'natmokval',
#    'id': 91160475,
#    'node_id': 'MDQ6VXNlcjkxMTYwNDc1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/91160475?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/natmokval',
#    'html_url': 'https://github.com/natmokval',
#    'followers_url': 'https://api.github.com/users/natmokval/followers',
#    'following_url': 'https://api.github.com/users/natmokval/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/natmokval/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/natmokval/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/natmokval/subscriptions',
#    'organizations_url': 'https://api.github.com/users/natmokval/orgs',
#    'repos_url': 'https://api.github.com/users/natmokval/repos',
#    'events_url': 'https://api.github.com/users/natmokval/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/natmokval/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-08-22T22:29:15Z',
#   'updated_at': '2023-08-23T10:49:23Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54696',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54696',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54696.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54696.patch',
#    'merged_at': None},
#   'body': 'Fix an example in doc/source/whatsnew/v0.13.0.rst, which raises an Error (see https://pandas.pydata.org/docs/dev/whatsnew/v0.13.0.html#enhancements)',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54696/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54696/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54695',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54695/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54695/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54695/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/54695',
#   'id': 1862152809,
#   'node_id': 'I_kwDOAA0YD85u_jJp',
#   'number': 54695,
#   'title': 'BUG: Formatting MultiIndex crashes if first column is too long',
#   'user': {'login': 'futurulus',
#    'id': 933453,
#    'node_id': 'MDQ6VXNlcjkzMzQ1Mw==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/933453?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/futurulus',
#    'html_url': 'https://github.com/futurulus',
#    'followers_url': 'https://api.github.com/users/futurulus/followers',
#    'following_url': 'https://api.github.com/users/futurulus/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/futurulus/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/futurulus/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/futurulus/subscriptions',
#    'organizations_url': 'https://api.github.com/users/futurulus/orgs',
#    'repos_url': 'https://api.github.com/users/futurulus/repos',
#    'events_url': 'https://api.github.com/users/futurulus/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/futurulus/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-08-22T20:22:41Z',
#   'updated_at': '2023-08-22T20:22:41Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\nprint(pd.MultiIndex.from_product([[\'a\'*58], [\'b\', \'c\']]))\n```\n\n\n### Issue Description\n\nRaises an exception in formatting:\r\n\r\n```\r\nTraceback (most recent call last):\r\n  File "/Users/monroe/Code/lexicon/grammar_strength/pandas_bug_1.py", line 2, in <module>\r\n    print(pd.MultiIndex.from_product([[\'a\'*58], [\'b\', \'c\']]))\r\n  File "/Users/monroe/.pyenv/versions/pyenv-39/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 1233, in __repr__\r\n    data = self._format_data()\r\n  File "/Users/monroe/.pyenv/versions/pyenv-39/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 1275, in _format_data\r\n    return format_object_summary(\r\n  File "/Users/monroe/.pyenv/versions/pyenv-39/lib/python3.9/site-packages/pandas/io/formats/printing.py", line 436, in format_object_summary\r\n    word = tail_item + sep + " "\r\nTypeError: can only concatenate tuple (not "str") to tuple\r\n```\n\n### Expected Behavior\n\nShould print a string representation of the index, something like\r\n```\r\nMultiIndex([(\'aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa\', \'b\'),\r\n            (\'aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa\', \'c\')],\r\n           )\r\n```\r\n(but possibly with truncation)\n\n### Installed Versions\n\n<details>\r\n\r\n```\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 0f437949513225922d851e9581723d82120684a6\r\npython           : 3.9.13.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 20.6.0\r\nVersion          : Darwin Kernel Version 20.6.0: Tue Jun 21 20:50:28 PDT 2022; root:xnu-7195.141.32~1/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 2.0.3\r\nnumpy            : 1.22.4\r\npytz             : 2022.2.1\r\ndateutil         : 2.8.2\r\nsetuptools       : 58.1.0\r\npip              : 23.1.2\r\nCython           : None\r\npytest           : 6.1.2\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : 4.9.2\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : 2.8.6\r\njinja2           : 3.1.2\r\nIPython          : None\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nbrotli           : 1.0.9\r\nfastparquet      : None\r\nfsspec           : 2023.5.0\r\ngcsfs            : None\r\nmatplotlib       : 3.5.3\r\nnumba            : 0.56.0\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : 3.0.10\r\npandas_gbq       : None\r\npyarrow          : 12.0.0\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.9.1\r\nsnappy           : \r\nsqlalchemy       : 1.4.41\r\ntables           : None\r\ntabulate         : 0.9.0\r\nxarray           : None\r\nxlrd             : 2.0.1\r\nzstandard        : None\r\ntzdata           : 2023.3\r\nqtpy             : None\r\npyqt5            : None\r\n```\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54695/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54695/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54687',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54687/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54687/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54687/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54687',
#   'id': 1861239432,
#   'node_id': 'PR_kwDOAA0YD85YfKX_',
#   'number': 54687,
#   'title': 'BUG: Fix astype str issue 54654',
#   'user': {'login': 'Itayazolay',
#    'id': 14018345,
#    'node_id': 'MDQ6VXNlcjE0MDE4MzQ1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/14018345?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Itayazolay',
#    'html_url': 'https://github.com/Itayazolay',
#    'followers_url': 'https://api.github.com/users/Itayazolay/followers',
#    'following_url': 'https://api.github.com/users/Itayazolay/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Itayazolay/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Itayazolay/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Itayazolay/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Itayazolay/orgs',
#    'repos_url': 'https://api.github.com/users/Itayazolay/repos',
#    'events_url': 'https://api.github.com/users/Itayazolay/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Itayazolay/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-08-22T11:15:16Z',
#   'updated_at': '2023-08-23T08:01:48Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54687',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54687',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54687.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54687.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #54654\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/v2.2.0.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54687/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54687/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54686',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54686/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54686/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54686/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/54686',
#   'id': 1861211626,
#   'node_id': 'I_kwDOAA0YD85u79Xq',
#   'number': 54686,
#   'title': 'BUG: can\'t install 2.1.0rc0. "Inconsistent version: expected \'2.1.0rc0\', but metadata has \'0+unknown\'"',
#   'user': {'login': 'sim-dt',
#    'id': 120720737,
#    'node_id': 'U_kgDOBzINYQ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/120720737?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sim-dt',
#    'html_url': 'https://github.com/sim-dt',
#    'followers_url': 'https://api.github.com/users/sim-dt/followers',
#    'following_url': 'https://api.github.com/users/sim-dt/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/sim-dt/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/sim-dt/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/sim-dt/subscriptions',
#    'organizations_url': 'https://api.github.com/users/sim-dt/orgs',
#    'repos_url': 'https://api.github.com/users/sim-dt/repos',
#    'events_url': 'https://api.github.com/users/sim-dt/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/sim-dt/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 129350,
# ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54654/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54654/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54653',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54653/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54653/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54653/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54653',
#   'id': 1858275287,
#   'node_id': 'PR_kwDOAA0YD85YVC-c',
#   'number': 54653,
#   'title': 'DOC: fix build failure with sphinx 7 and SOURCE_DATE_EPOCH',
#   'user': {'login': 'rebecca-palmer',
#    'id': 8066014,
#    'node_id': 'MDQ6VXNlcjgwNjYwMTQ=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8066014?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rebecca-palmer',
#    'html_url': 'https://github.com/rebecca-palmer',
#    'followers_url': 'https://api.github.com/users/rebecca-palmer/followers',
#    'following_url': 'https://api.github.com/users/rebecca-palmer/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rebecca-palmer/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rebecca-palmer/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rebecca-palmer/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rebecca-palmer/orgs',
#    'repos_url': 'https://api.github.com/users/rebecca-palmer/repos',
#    'events_url': 'https://api.github.com/users/rebecca-palmer/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rebecca-palmer/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-08-20T21:30:35Z',
#   'updated_at': '2023-08-22T16:37:38Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54653',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54653',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54653.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54653.patch',
#    'merged_at': None},
#   'body': "When SOURCE_DATE_EPOCH is set (which is the default when building Debian packages), Sphinx 7 [**requires** a space or comma after the year in 'copyright'](https://sources.debian.org/src/sphinx/7.1.2-2/sphinx/config.py/#L444).\r\n\r\n[Debian bug report, with failure log](https://bugs.debian.org/cgi-bin/bugreport.cgi?bug=1042672).\r\n\r\n- [not known to be reported here ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ n/a] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ CI says yes] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [n/a ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [no ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54653/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54653/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54651',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54651/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54651/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54651/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/54651',
#   'id': 1858222111,
#   'node_id': 'I_kwDOAA0YD85uwjgf',
#   'number': 54651,
#   'title': 'BUG: pd.to_sql fails with an ARRAY of composites',
#   'user': {'login': 'sergiykhan',
#    'id': 25179211,
#    'node_id': 'MDQ6VXNlcjI1MTc5MjEx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25179211?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sergiykhan',
#    'html_url': 'https://github.com/sergiykhan',
#    'followers_url': 'https://api.github.com/users/sergiykhan/followers',
#    'following_url': 'https://api.github.com/users/sergiykhan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/sergiykhan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/sergiykhan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/sergiykhan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/sergiykhan/orgs',
#    'repos_url': 'https://api.github.com/users/sergiykhan/repos',
#    'events_url': 'https://api.github.com/users/sergiykhan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/sergiykhan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-08-20T18:22:09Z',
#   'updated_at': '2023-08-21T01:56:55Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd\r\nfrom sqlalchemy import (\r\n    create_engine,\r\n    Column,\r\n    Table,\r\n    Text,\r\n    Integer,\r\n    select,\r\n)\r\nfrom sqlalchemy.orm import (\r\n    declarative_base,\r\n    sessionmaker,\r\n)\r\nfrom sqlalchemy.engine import (\r\n    URL,\r\n)\r\nfrom sqlalchemy_utils import (\r\n    CompositeType,\r\n)\r\nfrom sqlalchemy.dialects.postgresql import (\r\n    ARRAY,\r\n)\r\n\r\nengine = create_engine(\r\n    url=URL.create(\r\n        'postgresql',\r\n        username='',\r\n        database='',\r\n    ),\r\n)\r\n\r\nSession = sessionmaker(engine)\r\n\r\nBase = declarative_base()\r\n\r\ntable_name = 'test'\r\n\r\nfailure_mode = 2\r\n\r\nif failure_mode == 1:\r\n    # Option #1: Strings of length 1 in the composite type\r\n    # StatementError: (builtins.IndexError) string index out of range\r\n    df = pd.DataFrame(\r\n        {\r\n            'id': [1, 2],\r\n            'comp': [\r\n                [('aa', 't'), ('bb', 'tt')],\r\n                [('cc', 'tt'), ('dd', 'tt')],\r\n            ]\r\n        }\r\n    )\r\n    comp_type = CompositeType(\r\n        'comptype',\r\n        [\r\n            Column('A', Text),\r\n            Column('B', Text),\r\n        ]\r\n    )\r\n\r\nelif failure_mode == 2:\r\n    # Option #2: Integers in the composite type\r\n    # StatementError: (builtins.TypeError) 'int' object is not subscriptable\r\n    df = pd.DataFrame(\r\n        {\r\n            'id': [1, 2],\r\n            'comp': [\r\n                [('aa', 3), ('bb', 4)],\r\n                [('cc', 5), ('dd', 6)],\r\n            ]\r\n        }\r\n    )\r\n    comp_type = CompositeType(\r\n        'comptype',\r\n        [\r\n            Column('A', Text),\r\n            Column('B', Integer),\r\n        ]\r\n    )\r\n\r\n\r\nclass Test(Base):\r\n    __table__ = Table(\r\n        table_name,\r\n        Base.metadata,\r\n        Column('id', Integer, primary_key=True),\r\n        Column('comp', ARRAY(comp_type, dimensions=1)),\r\n    )\r\n\r\nBase.metadata.drop_all(engine, tables=[Base.metadata.tables[table_name]])\r\nBase.metadata.create_all(engine, tables=[Base.metadata.tables[table_name]])\r\n\r\nwith Session.begin() as session:\r\n    df.to_sql(\r\n        table_name,\r\n        con=session.connection(),\r\n        index=False,\r\n        if_exists='append',\r\n        dtype={\r\n            'comp': ARRAY(comp_type),\r\n        },\r\n    )\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nLet me say first that `to_sql()` appears to work fine with arrays of known Postgres data types, for example `ARRAY(Text)`.\r\n\r\nIn this case, I am writing an `ARRAY(composite_type)` into a Postgres table. The corresponding dataframe column contains a list of tuples, which correspond to the Postgres composite type.\r\n\r\nFirst, it appears that for composite types, one must specify the datatype in `dtype` to avoid the `DatatypeMismatch` error.\r\n\r\nSecond, `to_sql()` fails with different error messages depending on the specifics of the composite type or the actual data. For example, here are the two failure modes that I have discovered:\r\n\r\n1. a composite type contains an `Integer` results in `StatementError: (builtins.TypeError) 'int' object is not subscriptable`\r\n2. a composite type contains a `Text`, but one of the values is one-character long results in `StatementError: (builtins.IndexError) string index out of range`\r\n\r\nNote that if the composite type if made of `Text` fields only and all strings contain more than 1 char ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54651/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54651/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54649',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54649/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54649/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54649/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54649',
#   'id': 1858182626,
#   'node_id': 'PR_kwDOAA0YD85YUwlT',
#   'number': 54649,
#   'title': 'Updated documentation for pandas.DataFrame.map',
#   'user': {'login': 'DarthKitten2130',
#    'id': 72032381,
#    'node_id': 'MDQ6VXNlcjcyMDMyMzgx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72032381?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DarthKitten2130',
#    'html_url': 'https://github.com/DarthKitten2130',
#    'followers_url': 'https://api.github.com/users/DarthKitten2130/followers',
#    'following_url': 'https://api.github.com/users/DarthKitten2130/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/DarthKitten2130/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/DarthKitten2130/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/DarthKitten2130/subscriptions',
#    'organizations_url': 'https://api.github.com/users/DarthKitten2130/orgs',
#    'repos_url': 'https://api.github.com/users/DarthKitten2130/repos',
#    'events_url': 'https://api.github.com/users/DarthKitten2130/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/DarthKitten2130/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-08-20T16:36:23Z',
#   'updated_at': '2023-08-22T13:51:02Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54649',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54649',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54649.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54649.patch',
#    'merged_at': None},
#   'body': 'closes issue #54648 by adding another example of the map method using a standard func, along with additional keyword arguments.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54649/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54649/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
len(data1)
# Out:
# 30

# %%
data1[0]["user"]["id"]
# Out:
# 8519523

# %%
for i in range(len(data1)):
    print(data1[i]['user']['id'])
# Out:
# 8519523
# 10712109
# 136445532
# 136445532
# 136445532
# 7980521
# 39619011
# 10647082
# 91160475
# 933453
# 14018345
# 120720737
# 1020496
# 136131452
# 55560840
# 50613550
# 49668303
# 52504756
# 10647082
# 47963215
# 35587732
# 291575
# 1020496
# 14018345
# 5821660
# 4463796
# 14018345
# 8066014
# 25179211
# 72032381

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54707',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54707/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54707/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54707/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54707',
#   'id': 1863046827,
#   'node_id': 'PR_kwDOAA0YD85YlS1d',
#   'number': 54707,
#   'title': 'BUG: ArrowExtensionArray.fillna with duration types',
#   'user': {'login': 'lukemanley',
#    'id': 8519523,
#    'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lukemanley',
#    'html_url': 'https://github.com/lukemanley',
#    'followers_url': 'https://api.github.com/users/lukemanley/followers',
#    'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#    'repos_url': 'https://api.github.com/users/lukemanley/repos',
#    'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 3303158446,
#     'node_id': 'MDU6TGFiZWwzMzAzMTU4NDQ2',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Arrow',
#     'name': 'Arrow',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': 'pyarrow functionality'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-08-23T10:29:28Z',
#   'updated_at': '2023-08-23T10:32:02Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54707',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54707',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54707.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54707.patch',
#    'merged_at': None},
#   'body': '- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n\r\ncc @mroeschke - this expands on #54678 to cover a few more cases. \r\n\r\n\r\n\r\n\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54707/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54707/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54706',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54706/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54706/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54706/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/54706',
#   'id': 1862930076,
#   'node_id': 'I_kwDOAA0YD85vCg6c',
#   'number': 54706,
#   'title': 'BUG: creating dataframe from masked numpy array turns missing string values into NaN',
#   'user': {'login': 'mvashishtha',
#    'id': 10712109,
#    'node_id': 'MDQ6VXNlcjEwNzEyMTA5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10712109?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mvashishtha',
#    'html_url': 'https://github.com/mvashishtha',
#    'followers_url': 'https://api.github.com/users/mvashishtha/followers',
#    'following_url': 'https://api.github.com/users/mvashishtha/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mvashishtha/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mvashishtha/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mvashishtha/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mvashishtha/orgs',
#    'repos_url': 'https://api.github.com/users/mvashishtha/repos',
#    'events_url': 'https://api.github.com/users/mvashishtha/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mvashishtha/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-08-23T09:25:28Z',
#   'updated_at': '2023-08-23T09:40:07Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\nimport numpy as np\r\nimport numpy.ma as ma\r\n\r\nx = np.array(['a', 'b'])\r\nmx = ma.masked_array(x, mask=[0, 1])\r\nprint(pd.DataFrame(mx))\n```\n\n\n### Issue Description\n\ncreating dataframe from masked numpy array turns missing string values into NaN\n\n### Expected Behavior\n\nFor examples like this, where the masked array is of string dtype, I expect pandas to fill missing data with `None` instead of `NaN`.\n\n### Installed Versions\n\n<details>\r\n<summary>Details</summary>\r\n\r\n```\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 0f437949513225922d851e9581723d82120684a6\r\npython           : 3.8.16.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 22.5.0\r\nVersion          : Darwin Kernel Version 22.5.0: Mon Apr 24 20:51:50 PDT 2023; root:xnu-8796.121.2~5/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 2.0.3\r\nnumpy            : 1.24.4\r\npytz             : 2023.3\r\ndateutil         : 2.8.2\r\nsetuptools       : 67.8.0\r\npip              : 23.1.2\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : None\r\nIPython          : 8.12.2\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsnappy           : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nzstandard        : None\r\ntzdata           : 2023.3\r\nqtpy             : None\r\npyqt5            : None\r\n```\r\n\r\n</details>\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54706/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54706/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54705',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54705/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54705/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54705/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54705',
#   'id': 1862693327,
#   'node_id': 'PR_kwDOAA0YD85YkGis',
#   'number': 54705,
#   'title': 'DOC: updated date_format description for read_csv',
#   'user': {'login': 'rsm-23',
#    'id': 136445532,
#    'node_id': 'U_kgDOCCH-XA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/136445532?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rsm-23',
#    'html_url': 'https://github.com/rsm-23',
#    'followers_url': 'https://api.github.com/users/rsm-23/followers',
#    'following_url': 'https://api.github.com/users/rsm-23/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rsm-23/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rsm-23/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rsm-23/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rsm-23/orgs',
#    'repos_url': 'https://api.github.com/users/rsm-23/repos',
#    'events_url': 'https://api.github.com/users/rsm-23/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rsm-23/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-08-23T06:59:08Z',
#   'updated_at': '2023-08-23T06:59:08Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54705',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54705',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54705.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54705.patch',
#    'merged_at': None},
#   'body': '- [ ] xref #54285 \r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54705/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54705/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54704',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54704/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54704/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54704/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54704',
#   'id': 1862641777,
#   'node_id': 'PR_kwDOAA0YD85Yj7fX',
#   'number': 54704,
#   'title': 'DEPR: deprecated nonkeyword arguments in to_gbq',
#   'user': {'login': 'rsm-23',
#    'id': 136445532,
#    'node_id': 'U_kgDOCCH-XA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/136445532?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rsm-23',
#    'html_url': 'https://github.com/rsm-23',
#    'followers_url': 'https://api.github.com/users/rsm-23/followers',
#    'following_url': 'https://api.github.com/users/rsm-23/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rsm-23/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rsm-23/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rsm-23/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rsm-23/orgs',
#    'repos_url': 'https://api.github.com/users/rsm-23/repos',
#    'events_url': 'https://api.github.com/users/rsm-23/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rsm-23/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-08-23T06:18:06Z',
#   'updated_at': '2023-08-23T09:17:02Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54704',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54704',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54704.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54704.patch',
#    'merged_at': None},
#   'body': '- [x] xref #54229\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added an entry in the latest `doc/source/whatsnew/v2.2.0.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54704/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54704/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54703',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54703/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54703/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54703/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54703',
#   'id': 1862635701,
#   'node_id': 'PR_kwDOAA0YD85Yj6MG',
#   'number': 54703,
#   'title': 'DEPR: deprecated nonkeyword arguments in to_excel',
#   'user': {'login': 'rsm-23',
#    'id': 136445532,
#    'node_id': 'U_kgDOCCH-XA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/136445532?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rsm-23',
#    'html_url': 'https://github.com/rsm-23',
#    'followers_url': 'https://api.github.com/users/rsm-23/followers',
#    'following_url': 'https://api.github.com/users/rsm-23/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rsm-23/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rsm-23/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rsm-23/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rsm-23/orgs',
#    'repos_url': 'https://api.github.com/users/rsm-23/repos',
#    'events_url': 'https://api.github.com/users/rsm-23/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rsm-23/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-08-23T06:12:42Z',
#   'updated_at': '2023-08-23T09:16:24Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54703',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54703',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54703.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54703.patch',
#    'merged_at': None},
#   'body': '- [x] xref #54229 \r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added an entry in the latest `doc/source/whatsnew/v2.2.0.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54703/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54703/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54702',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54702/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54702/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54702/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/54702',
#   'id': 1862544294,
#   'node_id': 'I_kwDOAA0YD85vBCum',
#   'number': 54702,
#   'title': 'BUG: `pd.Timestamp()` only raises for nonexistent times when instantiated using str `ts_input`',
#   'user': {'login': 'leonoverweel',
#    'id': 7980521,
#    'node_id': 'MDQ6VXNlcjc5ODA1MjE=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7980521?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/leonoverweel',
#    'html_url': 'https://github.com/leonoverweel',
#    'followers_url': 'https://api.github.com/users/leonoverweel/followers',
#    'following_url': 'https://api.github.com/users/leonoverweel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/leonoverweel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/leonoverweel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/leonoverweel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/leonoverweel/orgs',
#    'repos_url': 'https://api.github.com/users/leonoverweel/repos',
#    'events_url': 'https://api.github.com/users/leonoverweel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/leonoverweel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-08-23T04:26:09Z',
#   'updated_at': '2023-08-23T04:41:40Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd\r\n\r\n# Nonexistent time, but doesn\'t raise:\r\nt1 = pd.Timestamp(2023, 3, 26, 2, 0, 0, tz="Europe/Amsterdam")\r\n\r\n# Same nonexistent time, but does raise:\r\nt2 = pd.Timestamp("2023-03-26 02:00", tz="Europe/Amsterdam")\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nWhen instantiating a nonexistent time, I would expect both ways of instantiating that time -- (1) using the `year`, `month`, `day`, `hour`, `minute` parameters and (2) using a (string) `ts_input` parameter -- to have the same result.\r\n\r\nHowever, option (1) happily accepts this nonexistent time, while option (2) correctly raises a `pytz.NonExistentTimeError`\r\n\r\n<details><summary>Full traceback</summary>\r\n\r\n```python\r\nTraceback (most recent call last):\r\n  File "../example.py", line 16, in <module>\r\n    dt2 = pd.Timestamp("2023-03-26 02:00", tz="Europe/Amsterdam")\r\n          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\r\n  File "pandas/_libs/tslibs/timestamps.pyx", line 1667, in pandas._libs.tslibs.timestamps.Timestamp.__new__\r\n  File "pandas/_libs/tslibs/conversion.pyx", line 280, in pandas._libs.tslibs.conversion.convert_to_tsobject\r\n  File "pandas/_libs/tslibs/conversion.pyx", line 547, in pandas._libs.tslibs.conversion.convert_str_to_tsobject\r\n  File "pandas/_libs/tslibs/tzconversion.pyx", line 177, in pandas._libs.tslibs.tzconversion.tz_localize_to_utc_single\r\n  File "pandas/_libs/tslibs/tzconversion.pyx", line 417, in pandas._libs.tslibs.tzconversion.tz_localize_to_utc\r\npytz.exceptions.NonExistentTimeError: 2023-03-26 02:00:00\r\n```\r\n\r\n</details> \r\n\r\n### Expected Behavior\r\n\r\nBoth options (1) and (2) for instantiating a nonexistent time should raise and tell me it\'s a nonexistent time.\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\n```\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 0f437949513225922d851e9581723d82120684a6\r\npython           : 3.11.4.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 22.3.0\r\nVersion          : Darwin Kernel Version 22.3.0: Mon Jan 30 20:38:37 PST 2023; root:xnu-8792.81.3~2/RELEASE_ARM64_T6000\r\nmachine          : arm64\r\nprocessor        : arm\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 2.0.3\r\nnumpy            : 1.25.2\r\npytz             : 2023.3\r\ndateutil         : 2.8.2\r\nsetuptools       : 68.0.0\r\npip              : 23.2.1\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : None\r\nIPython          : None\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsnappy           : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : Non ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54702/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54702/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54701',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54701/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54701/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54701/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54701',
#   'id': 1862539435,
#   'node_id': 'PR_kwDOAA0YD85Yjlmt',
#   'number': 54701,
#   'title': 'TST: added test for fixed bug  gh#50372',
#   'user': {'login': 'DRiXD',
#    'id': 39619011,
#    'node_id': 'MDQ6VXNlcjM5NjE5MDEx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39619011?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DRiXD',
#    'html_url': 'https://github.com/DRiXD',
#    'followers_url': 'https://api.github.com/users/DRiXD/followers',
#    'following_url': 'https://api.github.com/users/DRiXD/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/DRiXD/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/DRiXD/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/DRiXD/subscriptions',
#    'organizations_url': 'https://api.github.com/users/DRiXD/orgs',
#    'repos_url': 'https://api.github.com/users/DRiXD/repos',
#    'events_url': 'https://api.github.com/users/DRiXD/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/DRiXD/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-08-23T04:19:26Z',
#   'updated_at': '2023-08-23T06:20:20Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54701',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54701',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54701.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54701.patch',
#    'merged_at': None},
#   'body': '- [x] closes #50372 \r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests)\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n\r\nI added a test to prevent the bug described in GG#50372 from happening again.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54701/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54701/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54699',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54699/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54699/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54699/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54699',
#   'id': 1862361451,
#   'node_id': 'PR_kwDOAA0YD85YjATa',
#   'number': 54699,
#   'title': 'BUG: setitem with object type inserting Series maintains Series',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2822098,
#     'node_id': 'MDU6TGFiZWwyODIyMDk4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Indexing',
#     'name': 'Indexing',
#     'color': '0b02e1',
#     'default': False,
#     'description': 'Related to indexing on series/frames, not to indexes themselves'},
#    {'id': 2189479765,
#     'node_id': 'MDU6TGFiZWwyMTg5NDc5NzY1',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Nested%20Data',
#     'name': 'Nested Data',
#     'color': 'f2f989',
#     'default': False,
#     'description': 'Data where the values are collections (lists, sets, dicts, objects, etc.).'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/103',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103/labels',
#    'id': 9068593,
#    'node_id': 'MI_kwDOAA0YD84AimAx',
#    'number': 103,
#    'title': '2.1',
#    'description': 'on-merge: backport to 2.1.x',
#    'creator': {'login': 'phofl',
#     'id': 61934744,
#     'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/phofl',
#     'html_url': 'https://github.com/phofl',
#     'followers_url': 'https://api.github.com/users/phofl/followers',
#     'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#     'organizations_url': 'https://api.github.com/users/phofl/orgs',
#     'repos_url': 'https://api.github.com/users/phofl/repos',
#     'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/phofl/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 8,
#    'closed_issues': 1270,
#    'state': 'open',
#    'created_at': '2023-02-20T21:04:36Z',
#    'updated_at': '2023-08-23T03:02:11Z',
#    'due_on': '2023-08-20T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2023-08-23T00:15:22Z',
#   'updated_at': '2023-08-23T00:15:22Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54699',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54699',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54699.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54699.patch',
#    'merged_at': None},
#   'body': '- [x] closes #48933 (Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54699/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54699/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54696',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54696/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54696/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54696/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54696',
#   'id': 1862287718,
#   'node_id': 'PR_kwDOAA0YD85YiwaU',
#   'number': 54696,
#   'title': 'DOC: fix an example which raises an Error in v0.13.0.rst',
#   'user': {'login': 'natmokval',
#    'id': 91160475,
#    'node_id': 'MDQ6VXNlcjkxMTYwNDc1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/91160475?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/natmokval',
#    'html_url': 'https://github.com/natmokval',
#    'followers_url': 'https://api.github.com/users/natmokval/followers',
#    'following_url': 'https://api.github.com/users/natmokval/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/natmokval/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/natmokval/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/natmokval/subscriptions',
#    'organizations_url': 'https://api.github.com/users/natmokval/orgs',
#    'repos_url': 'https://api.github.com/users/natmokval/repos',
#    'events_url': 'https://api.github.com/users/natmokval/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/natmokval/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-08-22T22:29:15Z',
#   'updated_at': '2023-08-23T10:49:23Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54696',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54696',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54696.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54696.patch',
#    'merged_at': None},
#   'body': 'Fix an example in doc/source/whatsnew/v0.13.0.rst, which raises an Error (see https://pandas.pydata.org/docs/dev/whatsnew/v0.13.0.html#enhancements)',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54696/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54696/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54695',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54695/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54695/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54695/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/54695',
#   'id': 1862152809,
#   'node_id': 'I_kwDOAA0YD85u_jJp',
#   'number': 54695,
#   'title': 'BUG: Formatting MultiIndex crashes if first column is too long',
#   'user': {'login': 'futurulus',
#    'id': 933453,
#    'node_id': 'MDQ6VXNlcjkzMzQ1Mw==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/933453?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/futurulus',
#    'html_url': 'https://github.com/futurulus',
#    'followers_url': 'https://api.github.com/users/futurulus/followers',
#    'following_url': 'https://api.github.com/users/futurulus/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/futurulus/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/futurulus/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/futurulus/subscriptions',
#    'organizations_url': 'https://api.github.com/users/futurulus/orgs',
#    'repos_url': 'https://api.github.com/users/futurulus/repos',
#    'events_url': 'https://api.github.com/users/futurulus/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/futurulus/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-08-22T20:22:41Z',
#   'updated_at': '2023-08-22T20:22:41Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\nprint(pd.MultiIndex.from_product([[\'a\'*58], [\'b\', \'c\']]))\n```\n\n\n### Issue Description\n\nRaises an exception in formatting:\r\n\r\n```\r\nTraceback (most recent call last):\r\n  File "/Users/monroe/Code/lexicon/grammar_strength/pandas_bug_1.py", line 2, in <module>\r\n    print(pd.MultiIndex.from_product([[\'a\'*58], [\'b\', \'c\']]))\r\n  File "/Users/monroe/.pyenv/versions/pyenv-39/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 1233, in __repr__\r\n    data = self._format_data()\r\n  File "/Users/monroe/.pyenv/versions/pyenv-39/lib/python3.9/site-packages/pandas/core/indexes/base.py", line 1275, in _format_data\r\n    return format_object_summary(\r\n  File "/Users/monroe/.pyenv/versions/pyenv-39/lib/python3.9/site-packages/pandas/io/formats/printing.py", line 436, in format_object_summary\r\n    word = tail_item + sep + " "\r\nTypeError: can only concatenate tuple (not "str") to tuple\r\n```\n\n### Expected Behavior\n\nShould print a string representation of the index, something like\r\n```\r\nMultiIndex([(\'aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa\', \'b\'),\r\n            (\'aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa\', \'c\')],\r\n           )\r\n```\r\n(but possibly with truncation)\n\n### Installed Versions\n\n<details>\r\n\r\n```\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 0f437949513225922d851e9581723d82120684a6\r\npython           : 3.9.13.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 20.6.0\r\nVersion          : Darwin Kernel Version 20.6.0: Tue Jun 21 20:50:28 PDT 2022; root:xnu-7195.141.32~1/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 2.0.3\r\nnumpy            : 1.22.4\r\npytz             : 2022.2.1\r\ndateutil         : 2.8.2\r\nsetuptools       : 58.1.0\r\npip              : 23.1.2\r\nCython           : None\r\npytest           : 6.1.2\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : 4.9.2\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : 2.8.6\r\njinja2           : 3.1.2\r\nIPython          : None\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nbrotli           : 1.0.9\r\nfastparquet      : None\r\nfsspec           : 2023.5.0\r\ngcsfs            : None\r\nmatplotlib       : 3.5.3\r\nnumba            : 0.56.0\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : 3.0.10\r\npandas_gbq       : None\r\npyarrow          : 12.0.0\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.9.1\r\nsnappy           : \r\nsqlalchemy       : 1.4.41\r\ntables           : None\r\ntabulate         : 0.9.0\r\nxarray           : None\r\nxlrd             : 2.0.1\r\nzstandard        : None\r\ntzdata           : 2023.3\r\nqtpy             : None\r\npyqt5            : None\r\n```\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54695/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54695/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54687',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54687/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54687/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54687/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54687',
#   'id': 1861239432,
#   'node_id': 'PR_kwDOAA0YD85YfKX_',
#   'number': 54687,
#   'title': 'BUG: Fix astype str issue 54654',
#   'user': {'login': 'Itayazolay',
#    'id': 14018345,
#    'node_id': 'MDQ6VXNlcjE0MDE4MzQ1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/14018345?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Itayazolay',
#    'html_url': 'https://github.com/Itayazolay',
#    'followers_url': 'https://api.github.com/users/Itayazolay/followers',
#    'following_url': 'https://api.github.com/users/Itayazolay/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Itayazolay/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Itayazolay/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Itayazolay/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Itayazolay/orgs',
#    'repos_url': 'https://api.github.com/users/Itayazolay/repos',
#    'events_url': 'https://api.github.com/users/Itayazolay/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Itayazolay/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-08-22T11:15:16Z',
#   'updated_at': '2023-08-23T08:01:48Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54687',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54687',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54687.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54687.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #54654\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/v2.2.0.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54687/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54687/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54686',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54686/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54686/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54686/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/54686',
#   'id': 1861211626,
#   'node_id': 'I_kwDOAA0YD85u79Xq',
#   'number': 54686,
#   'title': 'BUG: can\'t install 2.1.0rc0. "Inconsistent version: expected \'2.1.0rc0\', but metadata has \'0+unknown\'"',
#   'user': {'login': 'sim-dt',
#    'id': 120720737,
#    'node_id': 'U_kgDOBzINYQ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/120720737?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sim-dt',
#    'html_url': 'https://github.com/sim-dt',
#    'followers_url': 'https://api.github.com/users/sim-dt/followers',
#    'following_url': 'https://api.github.com/users/sim-dt/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/sim-dt/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/sim-dt/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/sim-dt/subscriptions',
#    'organizations_url': 'https://api.github.com/users/sim-dt/orgs',
#    'repos_url': 'https://api.github.com/users/sim-dt/repos',
#    'events_url': 'https://api.github.com/users/sim-dt/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/sim-dt/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 129350,
# ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54654/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54654/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54653',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54653/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54653/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54653/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54653',
#   'id': 1858275287,
#   'node_id': 'PR_kwDOAA0YD85YVC-c',
#   'number': 54653,
#   'title': 'DOC: fix build failure with sphinx 7 and SOURCE_DATE_EPOCH',
#   'user': {'login': 'rebecca-palmer',
#    'id': 8066014,
#    'node_id': 'MDQ6VXNlcjgwNjYwMTQ=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8066014?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rebecca-palmer',
#    'html_url': 'https://github.com/rebecca-palmer',
#    'followers_url': 'https://api.github.com/users/rebecca-palmer/followers',
#    'following_url': 'https://api.github.com/users/rebecca-palmer/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rebecca-palmer/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rebecca-palmer/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rebecca-palmer/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rebecca-palmer/orgs',
#    'repos_url': 'https://api.github.com/users/rebecca-palmer/repos',
#    'events_url': 'https://api.github.com/users/rebecca-palmer/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rebecca-palmer/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-08-20T21:30:35Z',
#   'updated_at': '2023-08-22T16:37:38Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54653',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54653',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54653.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54653.patch',
#    'merged_at': None},
#   'body': "When SOURCE_DATE_EPOCH is set (which is the default when building Debian packages), Sphinx 7 [**requires** a space or comma after the year in 'copyright'](https://sources.debian.org/src/sphinx/7.1.2-2/sphinx/config.py/#L444).\r\n\r\n[Debian bug report, with failure log](https://bugs.debian.org/cgi-bin/bugreport.cgi?bug=1042672).\r\n\r\n- [not known to be reported here ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ n/a] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ CI says yes] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [n/a ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [no ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54653/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54653/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54651',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54651/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54651/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54651/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/54651',
#   'id': 1858222111,
#   'node_id': 'I_kwDOAA0YD85uwjgf',
#   'number': 54651,
#   'title': 'BUG: pd.to_sql fails with an ARRAY of composites',
#   'user': {'login': 'sergiykhan',
#    'id': 25179211,
#    'node_id': 'MDQ6VXNlcjI1MTc5MjEx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25179211?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sergiykhan',
#    'html_url': 'https://github.com/sergiykhan',
#    'followers_url': 'https://api.github.com/users/sergiykhan/followers',
#    'following_url': 'https://api.github.com/users/sergiykhan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/sergiykhan/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/sergiykhan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/sergiykhan/subscriptions',
#    'organizations_url': 'https://api.github.com/users/sergiykhan/orgs',
#    'repos_url': 'https://api.github.com/users/sergiykhan/repos',
#    'events_url': 'https://api.github.com/users/sergiykhan/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/sergiykhan/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-08-20T18:22:09Z',
#   'updated_at': '2023-08-21T01:56:55Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\nimport pandas as pd\r\nfrom sqlalchemy import (\r\n    create_engine,\r\n    Column,\r\n    Table,\r\n    Text,\r\n    Integer,\r\n    select,\r\n)\r\nfrom sqlalchemy.orm import (\r\n    declarative_base,\r\n    sessionmaker,\r\n)\r\nfrom sqlalchemy.engine import (\r\n    URL,\r\n)\r\nfrom sqlalchemy_utils import (\r\n    CompositeType,\r\n)\r\nfrom sqlalchemy.dialects.postgresql import (\r\n    ARRAY,\r\n)\r\n\r\nengine = create_engine(\r\n    url=URL.create(\r\n        'postgresql',\r\n        username='',\r\n        database='',\r\n    ),\r\n)\r\n\r\nSession = sessionmaker(engine)\r\n\r\nBase = declarative_base()\r\n\r\ntable_name = 'test'\r\n\r\nfailure_mode = 2\r\n\r\nif failure_mode == 1:\r\n    # Option #1: Strings of length 1 in the composite type\r\n    # StatementError: (builtins.IndexError) string index out of range\r\n    df = pd.DataFrame(\r\n        {\r\n            'id': [1, 2],\r\n            'comp': [\r\n                [('aa', 't'), ('bb', 'tt')],\r\n                [('cc', 'tt'), ('dd', 'tt')],\r\n            ]\r\n        }\r\n    )\r\n    comp_type = CompositeType(\r\n        'comptype',\r\n        [\r\n            Column('A', Text),\r\n            Column('B', Text),\r\n        ]\r\n    )\r\n\r\nelif failure_mode == 2:\r\n    # Option #2: Integers in the composite type\r\n    # StatementError: (builtins.TypeError) 'int' object is not subscriptable\r\n    df = pd.DataFrame(\r\n        {\r\n            'id': [1, 2],\r\n            'comp': [\r\n                [('aa', 3), ('bb', 4)],\r\n                [('cc', 5), ('dd', 6)],\r\n            ]\r\n        }\r\n    )\r\n    comp_type = CompositeType(\r\n        'comptype',\r\n        [\r\n            Column('A', Text),\r\n            Column('B', Integer),\r\n        ]\r\n    )\r\n\r\n\r\nclass Test(Base):\r\n    __table__ = Table(\r\n        table_name,\r\n        Base.metadata,\r\n        Column('id', Integer, primary_key=True),\r\n        Column('comp', ARRAY(comp_type, dimensions=1)),\r\n    )\r\n\r\nBase.metadata.drop_all(engine, tables=[Base.metadata.tables[table_name]])\r\nBase.metadata.create_all(engine, tables=[Base.metadata.tables[table_name]])\r\n\r\nwith Session.begin() as session:\r\n    df.to_sql(\r\n        table_name,\r\n        con=session.connection(),\r\n        index=False,\r\n        if_exists='append',\r\n        dtype={\r\n            'comp': ARRAY(comp_type),\r\n        },\r\n    )\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nLet me say first that `to_sql()` appears to work fine with arrays of known Postgres data types, for example `ARRAY(Text)`.\r\n\r\nIn this case, I am writing an `ARRAY(composite_type)` into a Postgres table. The corresponding dataframe column contains a list of tuples, which correspond to the Postgres composite type.\r\n\r\nFirst, it appears that for composite types, one must specify the datatype in `dtype` to avoid the `DatatypeMismatch` error.\r\n\r\nSecond, `to_sql()` fails with different error messages depending on the specifics of the composite type or the actual data. For example, here are the two failure modes that I have discovered:\r\n\r\n1. a composite type contains an `Integer` results in `StatementError: (builtins.TypeError) 'int' object is not subscriptable`\r\n2. a composite type contains a `Text`, but one of the values is one-character long results in `StatementError: (builtins.IndexError) string index out of range`\r\n\r\nNote that if the composite type if made of `Text` fields only and all strings contain more than 1 char ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54651/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54651/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54649',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54649/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54649/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54649/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/54649',
#   'id': 1858182626,
#   'node_id': 'PR_kwDOAA0YD85YUwlT',
#   'number': 54649,
#   'title': 'Updated documentation for pandas.DataFrame.map',
#   'user': {'login': 'DarthKitten2130',
#    'id': 72032381,
#    'node_id': 'MDQ6VXNlcjcyMDMyMzgx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72032381?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DarthKitten2130',
#    'html_url': 'https://github.com/DarthKitten2130',
#    'followers_url': 'https://api.github.com/users/DarthKitten2130/followers',
#    'following_url': 'https://api.github.com/users/DarthKitten2130/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/DarthKitten2130/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/DarthKitten2130/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/DarthKitten2130/subscriptions',
#    'organizations_url': 'https://api.github.com/users/DarthKitten2130/orgs',
#    'repos_url': 'https://api.github.com/users/DarthKitten2130/repos',
#    'events_url': 'https://api.github.com/users/DarthKitten2130/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/DarthKitten2130/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-08-20T16:36:23Z',
#   'updated_at': '2023-08-22T13:51:02Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/54649',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/54649',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/54649.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/54649.patch',
#    'merged_at': None},
#   'body': 'closes issue #54648 by adding another example of the map method using a standard func, along with additional keyword arguments.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54649/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/54649/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
pd.DataFrame(data1,columns=['url','repository_url','labels_url'])
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...

# %%
df2 = pd.DataFrame(data1,columns=['id','url','repository_url','labels_url','user'])

# %%
df2
# Out:
#             id                                                url  \
# 0   1863046827  https://api.github.com/repos/pandas-dev/pandas...
# 1   1862930076  https://api.github.com/repos/pandas-dev/pandas...
# 2   1862693327  https://api.github.com/repos/pandas-dev/pandas...
# 3   1862641777  https://api.github.com/repos/pandas-dev/pandas...
# 4   1862635701  https://api.github.com/repos/pandas-dev/pandas...
# 5   1862544294  https://api.github.com/repos/pandas-dev/pandas...
# 6   1862539435  https://api.github.com/repos/pandas-dev/pandas...
# 7   1862361451  https://api.github.com/repos/pandas-dev/pandas...
# 8   1862287718  https://api.github.com/repos/pandas-dev/pandas...
# 9   1862152809  https://api.github.com/repos/pandas-dev/pandas...
# 10  1861239432  https://api.github.com/repos/pandas-dev/pandas...
# 11  1861211626  https://api.github.com/repos/pandas-dev/pandas...
# 12  1860933826  https://api.github.com/repos/pandas-dev/pandas...
# 13  1860614640  https://api.github.com/repos/pandas-dev/pandas...
# 14  1860306365  https://api.github.com/repos/pandas-dev/pandas...
# 15  1860280020  https://api.github.com/repos/pandas-dev/pandas...
# 16  1860210094  https://api.github.com/repos/pandas-dev/pandas...
# 17  1860026324  https://api.github.com/repos/pandas-dev/pandas...
# 18  1859900871  https://api.github.com/repos/pandas-dev/pandas...
# 19  1859834534  https://api.github.com/repos/pandas-dev/pandas...
# 20  1859781705  https://api.github.com/repos/pandas-dev/pandas...
# 21  1859583020  https://api.github.com/repos/pandas-dev/pandas...
# 22  1859284386  https://api.github.com/repos/pandas-dev/pandas...
# 23  1859151730  https://api.github.com/repos/pandas-dev/pandas...
# 24  1858727363  https://api.github.com/repos/pandas-dev/pandas...
# 25  1858492723  https://api.github.com/repos/pandas-dev/pandas...
# 26  1858285780  https://api.github.com/repos/pandas-dev/pandas...
# 27  1858275287  https://api.github.com/repos/pandas-dev/pandas...
# 28  1858222111  https://api.github.com/repos/pandas-dev/pandas...
# 29  1858182626  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                  user
# 0   {'login': 'lukemanley', 'id': 8519523, 'node_i...
# 1   {'login': 'mvashishtha', 'id': 10712109, 'node...
# 2   {'login': 'rsm-23', 'id': 136445532, 'node_id'...
# 3   {'login': 'rsm-23', 'id': 136445532, 'node_id'...
# 4   {'login': 'rsm-23', 'id': 136445532, 'node_id'...
# 5   {'login': 'leonoverweel', 'id': 7980521, 'node...
# 6   {'login': 'DRiXD', 'id': 39619011, 'node_id': ...
# 7   {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 8   {'login': 'natmokval', 'id': 91160475, 'node_i...
# 9   {'login': 'futurulus', 'id': 933453, 'node_id'...
# 10  {'login': 'Itayazolay', 'id': 14018345, 'node_...
# 11  {'login': 'sim-dt', 'id': 120720737, 'node_id'...
# 12  {'login': 'jorisvandenbossche', 'id': 1020496,...
# 13  {'login': 'salujaditi14', 'id': 136131452, 'no...
# 14  {'login': 'kvn4', 'id': 55560840, 'node_id': '...
# 15  {'login': 'JonahBreslow', 'id': 50613550, 'nod...
# 16  {'login': 'sammcbeth', 'id': 49668303, 'node_i...
# 17  {'login': 'maharris77', 'id': 52504756, 'node_...
# 18  {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 19  {'login': 'lithomas1', 'id': 47963215, 'node_i...
# 20  {'login': 'vijayakumarpattanashetti', 'id': 35...
# 21  {'login': 'flying-sheep', 'id': 291575, 'node_...
# 22  {'login': 'jorisvandenbossche', 'id': 1020496,...
# 23  {'login': 'Itayazolay', 'id': 14018345, 'node_...
# 24  {'login': 'kmuehlbauer', 'id': 5821660, 'node_...
# 25  {'login': 'ChillarAnand', 'id': 4463796, 'node...
# 26  {'login': 'Itayazolay', 'id': 14018345, 'node_...
# 27  {'login': 'rebecca-palmer', 'id': 8066014, 'no...
# 28  {'login': 'sergiykhan', 'id': 25179211, 'node_...
# 29  {'login': 'DarthKitten2130', 'id': 72032381, '...

# %%
df2.to_csv("json_res.csv")

# %%
ls
# Out:
#  addresses.csv
#  contacts.csv
#  holiday_schedules.csv
#  json_res.csv
#  locations.csv
# 'LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx'
# 'LUSID Excel - Maintain a product in multiple currencies and share classes.xlsx'
# 'LUSID Excel - Manage instruments with economic definitions.xlsx'
# 'LUSID Excel - Manage Orders.xlsx'
# 'LUSID Excel - Manage your investment strategies.xlsx'
# 'LUSID Excel - Setting up your IBOR.xlsx'
# 'LUSID Excel - Setting up your market data.xlsx'
#  mail_addresses.csv
#  NBA.csv
#  organizations.csv
#  pandas-2.ipynb
#  Pandas.ipynb
#  phones.csv
#  programs.csv
#  regular_schedules.csv
#  services.csv
#  taxonomy.csv
