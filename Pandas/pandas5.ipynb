# %%
print("Last Pandas Class")
# Out:
# Last Pandas Class

# %%
import pandas as pd

# %%
df = pd.DataFrame({'col1':[1,2,3,4,5],
              'col2':[234,534,454,546,456],
              'col3':"sagar prakash giradkar pauna kurd".split()
    
})

# %%
"sagar prakash giradkar pauna kurd".split()
# Out:
# ['sagar', 'prakash', 'giradkar', 'pauna', 'kurd']

# %%
df
# Out:
#    col1  col2      col3
# 0     1   234     sagar
# 1     2   534   prakash
# 2     3   454  giradkar
# 3     4   546     pauna
# 4     5   456      kurd

# %%
df['col4'] = df['col1']**2

# %%
df
# Out:
#    col1  col2      col3  col4
# 0     1   234     sagar     1
# 1     2   534   prakash     4
# 2     3   454  giradkar     9
# 3     4   546     pauna    16
# 4     5   456      kurd    25

# %%
df["col5"] = df["col3"].str[0]

# %%
df
# Out:
#    col1  col2      col3  col4 col5
# 0     1   234     sagar     1    s
# 1     2   534   prakash     4    p
# 2     3   454  giradkar     9    g
# 3     4   546     pauna    16    p
# 4     5   456      kurd    25    k

# %%
df["col5"] = df["col3"].str[0]

# %%
df
# Out:
#    col1  col2      col3  col4 col5
# 0     1   234     sagar     1    s
# 1     2   534   prakash     4    p
# 2     3   454  giradkar     9    g
# 3     4   546     pauna    16    p
# 4     5   456      kurd    25    k

# %%
def test(a):
    return a**2

# %%
df["col4_4"] = df["col1"].apply(test)

# %%
df
# Out:
#    col1  col2      col3  col4 col5  col4_4
# 0     1   234     sagar     1    s       1
# 1     2   534   prakash     4    p       4
# 2     3   454  giradkar     9    g       9
# 3     4   546     pauna    16    p      16
# 4     5   456      kurd    25    k      25

# %%
def test2(a):
    l = []
    if(a == 's'):
        return 's'
    else:
        return 'z'

# %%
df["col5_5"] =df["col5"].apply(test2)

# %%
df
# Out:
#    col1  col2      col3  col4 col5  col4_4 col5_5
# 0     1   234     sagar     1    s       1      s
# 1     2   534   prakash     4    p       4      z
# 2     3   454  giradkar     9    g       9      z
# 3     4   546     pauna    16    p      16      z
# 4     5   456      kurd    25    k      25      z

# %%
df['col6_6'] = df["col5"].apply(lambda a:"s" if(a == 's') else 'z')

# %%
df
# Out:
#    col1  col2      col3  col4 col5  col4_4 col5_5 col6_6
# 0     1   234     sagar     1    s       1      s      s
# 1     2   534   prakash     4    p       4      z      z
# 2     3   454  giradkar     9    g       9      z      z
# 3     4   546     pauna    16    p      16      z      z
# 4     5   456      kurd    25    k      25      z      z

# %%
df["col7"] = df["col3"].apply(len)

# %%
df
# Out:
#    col1  col2      col3  col4 col5  col4_4 col5_5 col6_6  col7
# 0     1   234     sagar     1    s       1      s      s     5
# 1     2   534   prakash     4    p       4      z      z     7
# 2     3   454  giradkar     9    g       9      z      z     8
# 3     4   546     pauna    16    p      16      z      z     5
# 4     5   456      kurd    25    k      25      z      z     4

# %%
import math
df["col8"] = df["col2"].apply(math.log)

# %%
df
# Out:
#    col1  col2      col3  col4 col5  col4_4 col5_5 col6_6  col7      col8
# 0     1   234     sagar     1    s       1      s      s     5  5.455321
# 1     2   534   prakash     4    p       4      z      z     7  6.280396
# 2     3   454  giradkar     9    g       9      z      z     8  6.118097
# 3     4   546     pauna    16    p      16      z      z     5  6.302619
# 4     5   456      kurd    25    k      25      z      z     4  6.122493

# %%
# !pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /usr/lib/python3/dist-packages (1.24.2)
